# %%
import tweepy
from textblob import TextBlob

cunsumer_key = "12Q2zTExR0HLwKNTPsoh0hr3j"
consumer_keys_secret = "znlqDAjoNCxsZOvTKOdzP1CtdFDeGfG8Ht8ucGaZVEMLnuCKvW"

access_token = "1091638659164426240-1WNI4vpObJiRea2DJb3oPZ0DUXrdCp"
access_token_secret = "10THXbtdE7zzghprXHVH9aiGXJJGOPXdInJytbUnRnEFe"

auth = tweepy.OAuthHandler(cunsumer_key,consumer_keys_secret)
auth.set_access_token(access_token,access_token_secret)

api = tweepy.API(auth)

public_tweets = api.search_tweets("akshay kumar")

for tweet in public_tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    if(analysis.sentiment[0]>0):
        print("positive")
    elif(analysis.sentiment[0]<0):
        print("negative")
    else:
        print("neutral")
# Out:
# RT @ZeeNewsEnglish: #DidYouKnow: 'Prithviraj' makers created over 50,000 costumes, 500 turbans for the Akshay Kumar-starrer
#
# #Prithviraj
# ht…
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# RT @Bhagchand_Ak: Samraat Prithviraj Chauhan was a great warrior, brave and dignified king. Dr Chandra Prakash Dwivedi ji has ensured to pr…
# Sentiment(polarity=0.8, subjectivity=0.875)
# positive
# RT @ABPNews: फिल्म 'पृथ्वीराज' को लेकर एक नई जानकारी सामने आ रही है जो काफी चौंकाने वाली है.
#
# #Prithviraj #Entertainment #AkshayKumar
#
# http…
# Sentiment(polarity=0.0, subjectivity=0.0)
# neutral
# RT @Bhagchand_Ak: Samraat Prithviraj Chauhan was a great warrior, brave and dignified king. Dr Chandra Prakash Dwivedi ji has ensured to pr…
# Sentiment(polarity=0.8, subjectivity=0.875)
# positive
# RT @first_issues: Make this app better in whatever manner you want https://t.co/bgjIF4s1rE #github #JavaScript #CSS #HTML
# Sentiment(polarity=0.5, subjectivity=0.5)
# positive
# ...
